# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/algend/Desktop/WeatherPy/combined_weather_data.csv')

df.head()
# Out:
#            name country  cloudliness        date  humidity  maximum temp  \
# 0      Ghauspur      PK           40  1549814400        55         62.60
# 1          Okha      RU           48  1549816190        83         -8.81
# 2     Busselton      AU            0  1549816191       100         62.93
# 3       Sibolga      ID           76  1549816191       100         70.22
# 4  Punta Arenas      CL           75  1549814400        45         46.40
#
#    latitude  longitude  windspeed
# 0     28.14      69.08       4.70
# 1     53.59     142.95      10.20
# 2    -33.64     115.35      17.02
# 3      1.74      98.78       2.26
# 4    -53.16     -70.91      11.41

# %%
convert_csv_to_html=df.to_html()
convert_csv_to_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>name</th>\n      <th>country</th>\n      <th>cloudliness</th>\n      <th>date</th>\n      <th>humidity</th>\n      <th>maximum temp</th>\n      <th>latitude</th>\n      <th>longitude</th>\n      <th>windspeed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Ghauspur</td>\n      <td>PK</td>\n      <td>40</td>\n      <td>1549814400</td>\n      <td>55</td>\n      <td>62.60</td>\n      <td>28.14</td>\n      <td>69.08</td>\n      <td>4.70</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Okha</td>\n      <td>RU</td>\n      <td>48</td>\n      <td>1549816190</td>\n      <td>83</td>\n      <td>-8.81</td>\n      <td>53.59</td>\n      <td>142.95</td>\n      <td>10.20</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Busselton</td>\n      <td>AU</td>\n      <td>0</td>\n      <td>1549816191</td>\n      <td>100</td>\n      <td>62.93</td>\n      <
# ...

# %%
df.to_html('table.html')
